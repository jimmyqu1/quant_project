# %%
import pandas as pd

# %%
data = pd.read_csv("all_factor_data.csv",index_col=0)

# %%
data = data.set_index([data.index,'code'])

# %%
#结构是一个Multiindex 的结构 不太会用的话可以谷歌一下 level0的索引是因子名 level1是股票代码
data
# Out:
#                                          2014-07-24  2014-07-25  2014-07-28  \
#                             code
# market_cap                  000001.XSHE    4.378863    4.390434    4.419177
#                             000002.XSHE    4.378863    4.390434    4.419177
#                             000004.XSHE   -0.641681   -0.638678   -0.634676
#                             000005.XSHE   -0.568121   -0.567840   -0.564394
#                             000006.XSHE   -0.091151   -0.100122   -0.108409
# ...                                             ...         ...         ...
# inc_net_profit_year_on_year 688066.XSHG         NaN         NaN         NaN
#                             688088.XSHG         NaN         NaN         NaN
#                             688122.XSHG         NaN         NaN         NaN
#                             688333.XSHG         NaN         NaN         NaN
#                             688388.XSHG         NaN         NaN         NaN
#
# ...

# %%
#这里是所有因子 具体因子说明在Excel里 （pe、pb、ps、pcf做了倒数处理）
#其他一些如这五年所有交易日 股票基本信息等资料我也上传了
factors_set = ['market_cap','circulating_market_cap','turnover_ratio','1/pe_ratio',
               '1/pe_ratio_lyr','1/pb_ratio','1/ps_ratio','1/pcf_ratio','eps','roe',
               'inc_return','roa','net_profit_margin','gross_profit_margin','inc_net_profit_year_on_year']

# %%
data.loc["1/pe_ratio"].head() #选取因子
# Out:
#              2014-07-24  2014-07-25  2014-07-28  2014-07-29  2014-07-30  \
# code
# 000001.XSHE   -0.043935   -0.046041   -0.044546   -0.043328   -0.043750
# 000002.XSHE    1.218666    1.220832    1.243591    1.200084    1.251629
# 000004.XSHE   -0.059766   -0.062217   -0.064175   -0.062355   -0.053654
# 000005.XSHE   -1.061263   -1.054335   -1.043775   -1.040471   -1.032225
# 000006.XSHE    1.371073    1.395147    1.408442    1.434248    1.489152
#
#              2014-07-31  2014-08-01  2014-08-04  2014-08-05  2014-08-06  ...  \
# code                                                                     ...
# 000001.XSHE   -0.042902   -0.042969   -0.042851   -0.044023   -0.045406  ...
# 000002.XSHE    1.265580    1.254811    1.215635    1.238610    1.249855  ...
# 000004.XSHE   -0.065866   -0.048987   -0.056180   -0.060759   -0.059343  ...
# 000005.XSHE   -1.045028   -1.049975   -1.054569   -1.046656   -1.041174  ...
# ...
